# %%
# Coursera_Capstone

# %%
# This Notebook will be used for Capstone Project for the "Data Analytics with Python" Coursera Series

# %%
# !conda install -c conda-forge folium 
import numpy as np
import pandas as pd
import folium
import requests
print('Hello Capstone Project Course!')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Hello Capstone Project Course!

# %% [markdown]
# ## Capstone Week 3
# ### First Requirement

# %%
# Getting the Toronto data for Coursera Capstone: Week 3
# NOTE: This satisfies the first submission requirement
wiki_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wikidf = pd.read_html(wiki_url)[0]
wikidf
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# ...

# %%
# cleaning the data
#
# drop rows with any 'NA' data
wikidf.dropna(axis='index',inplace=True)
# drop rows with Borough=='Not assigned'
wikidf = wikidf.loc[wikidf['Borough']!='Not assigned']
# if a neighbouhood is 'Not assigned', assign it equal to its bourough
wikidf['Neighbourhood'] = wikidf.apply(
    lambda row: row['Borough'] if row['Neighbourhood'] == 'Not assigned' else row['Neighbourhood'],
    axis=1
)
# combine rows with the same Postcode/Borough into a single row with neighborhoods separated by commas
wikidf = wikidf.groupby('Postcode',as_index=False).agg(lambda x:','.join(set(x)))
wikidf
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# ...

# %%
# Get the latitude and longitude data for Toronto neighborhoods
#
lldf = pd.read_csv('https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv')
lldf
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %% [markdown]
# ## Capstone Week 3
# ### Second Requirement

# %%
# Join the two data frames into a single 
# data frame combining neighborhoods with
# latitude and longitude data
########################################################
# NOTE: This satisfies the second submission requirement
########################################################
lldf.columns = ['Postcode', 'Latitude','Longitude']
wikidf.set_index('Postcode')
lldf.set_index('Postcode')
#df = pd.concat([wikidf,lldf],axis=1,join='inner')
df = pd.merge(wikidf,lldf,on='Postcode')
df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
# Explore Neighborhoods in Toronto
# Refine dataset to only include 
# Boroughs that contains some form
# of the string 'Toronto' in them
toronto_mask = df['Borough'].str.contains('Toronto',regex=False)
tdf = df[toronto_mask]
tdf
# Out:
#    Postcode           Borough  \
# 37      M4E      East Toronto
# 41      M4K      East Toronto
# 42      M4L      East Toronto
# 43      M4M      East Toronto
# 44      M4N   Central Toronto
# 45      M4P   Central Toronto
# 46      M4R   Central Toronto
# 47      M4S   Central Toronto
# 48      M4T   Central Toronto
# 49      M4V   Central Toronto
# 50      M4W  Downtown Toronto
# 51      M4X  Downtown Toronto
# 52      M4Y  Downtown Toronto
# 53      M5A  Downtown Toronto
# 54      M5B  Downtown Toronto
# 55      M5C  Downtown Toronto
# 56      M5E  Downtown Toronto
# 57      M5G  Downtown Toronto
# 58      M5H  Downtown Toronto
# 59      M5J  Downtown Toronto
# 60      M5K  Downtown Toronto
# 61      M5L  Downtown Toronto
# 63      M5N   Central Toronto
# 64      M5P   Central Toronto
# 65      M5R   Central Toronto
# 66      M5S  Downtown Toronto
# 67      M5T  Downtown Toronto
# 68      M5V  Downtown Toronto
# 69      M5W  Downtown Toronto
# 70      M5X  Downtown Toronto
# ...

# %% [markdown]
# ## Capstone Week 3
# ### Third Requirement

# %%
# Create map of Toronto

toronto_latitude = 43.6532
toronto_longitude = -79.3832
map_toronto = folium.Map(location=[toronto_latitude, toronto_longitude], zoom_start=13)

# %%
# Add neighbourhood data to folium map
#
for lat, lng, borough, neighborhood in zip(tdf['Latitude'], tdf['Longitude'], tdf['Borough'], tdf['Neighbourhood']):
  label = '{},{}'.format(neighborhood,borough)
  label = folium.Popup(label, parse_html=True)
  folium.CircleMarker(
      [lat, lng],
      radius=5,
      popup=label,
      color='blue',
      fill=True,
      fill_color='#3186cc',
      fill_opacity=0.7).add_to(map_toronto)

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Get popular venues in Toronto from FourSqurare
VERSION = '20190701'
radius = '15000'
LIMIT = '50'
# Get FourSquare data for Toronto
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(    
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    toronto_latitude, 
    toronto_longitude, 
    radius, 
    LIMIT)
results = requests.get(url).json()

# %%
# Process FourSquare results into useable data frame
# for displaying the top 50 popular venues around
# Toronto on the folio map we are creating
venues = results['response']['groups'][0]['items']
nearby_venues = pd.io.json.json_normalize(venues)
# filter columns
nearby_venues =nearby_venues.loc[:, ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']]
# filter the category for each row
def extract_cat_name(x):
    return x[1][0]['name'].replace("'","")
def replace_name_quotes(x):
    return(x[0].replace("'",""))
nearby_venues['venue.categories'] = nearby_venues.apply(extract_cat_name, axis=1)
nearby_venues['venue.name'] = nearby_venues.apply(replace_name_quotes, axis=1)
nearby_venues
# Out:
#                                      venue.name           venue.categories  \
# 0                              Downtown Toronto               Neighborhood
# 1                              Richmond Station        American Restaurant
# 2              Elgin And Winter Garden Theatres                    Theater
# 3                                           Pai            Thai Restaurant
# 4                                   UNIQLO ユニクロ             Clothing Store
# 5                                Byblos Toronto   Mediterranean Restaurant
# 6                        Nathan Phillips Square                      Plaza
# 7                        Art Gallery of Ontario                Art Gallery
# 8                                  Banh Mi Boys             Sandwich Place
# 9                            Shangri-La Toronto                      Hotel
# 10                           Equinox Bay Street                        Gym
# ...

# %%
# add venues and dispay map
for lat, lng, name, cat in zip(nearby_venues['venue.location.lat'], nearby_venues['venue.location.lng'], nearby_venues['venue.name'], nearby_venues['venue.categories']):
  label = '{}, {}'.format(name,cat)
  label = folium.Popup(label, parse_html=True)
  folium.CircleMarker(
      [lat, lng],
      radius=5,
      popup=label,
      color='green',
      fill=True,
      fill_color='#3186cc',
      fill_opacity=0.7).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
